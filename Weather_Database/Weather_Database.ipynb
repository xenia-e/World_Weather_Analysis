# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the API key.
from config import weather_api_key
# Import the time module.
import time
# Import linregress
from scipy.stats import linregress

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=59073a7282868a59862fa5b9847711f9'

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | rajanpur
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | borovoy
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | puerto colombia
# Processing Record 7 of Set 1 | ambilobe
# Processing Record 8 of Set 1 | tricase
# Processing Record 9 of Set 1 | clyde river
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | chuy
# Processing Record 12 of Set 1 | warrnambool
# Processing Record 13 of Set 1 | izumo
# Processing Record 14 of Set 1 | sitka
# Processing Record 15 of Set 1 | anloga
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | ust-omchug
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 20 of Set 1 | pachperwa
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | katsuura
# Processing Record 24 of Set 1 | upernavik
# Processing Record 25 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 1 | bukachacha
# Processing Record 27 of Set 1 | ahipara
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | honiara
# Processing Record 30 of Set 1 | hithadhoo
# Processing Record 31 of Set 1 | alofi
# Processing Record 32 of Set 1 | oranjestad
# Processing Record 33 of Set 1 | kampong chhnang
# Processing Record 34 of Set 1 | bull savanna
# Processing Record 35 of Set 1 | muros
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | cherskiy
# Processing Record 38 of Set 1 | saint-francois
# Processing Record 39 of Set 1 | urdoma
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | siocon
# Processing Record 42 of Set 1 | nikolskoye
# Processing Record 43 of Set 1 | saint-leu
# Processing Record 44 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 1 | loiza
# Processing Record 46 of Set 1 | hasaki
# Processing Record 47 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 1 | wuda
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | varkaus
# Processing Record 1 of Set 2 | nanortalik
# Processing Record 2 of Set 2 | rikitea
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | paamiut
# Processing Record 5 of Set 2 | victoria
# Processing Record 6 of Set 2 | luderitz
# Processing Record 7 of Set 2 | aykhal
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | kasulu
# Processing Record 10 of Set 2 | boguchany
# Processing Record 11 of Set 2 | agropoli
# Processing Record 12 of Set 2 | hamilton
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | kavieng
# Processing Record 16 of Set 2 | ashta
# Processing Record 17 of Set 2 | kapaa
# Processing Record 18 of Set 2 | inhambane
# Processing Record 19 of Set 2 | remontnoye
# Processing Record 20 of Set 2 | peniche
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | dunedin
# Processing Record 23 of Set 2 | carnarvon
# Processing Record 24 of Set 2 | jadu
# Processing Record 25 of Set 2 | ketchikan
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | arlit
# Processing Record 28 of Set 2 | angra
# City not found. Skipping...
# Processing Record 29 of Set 2 | vardo
# Processing Record 30 of Set 2 | laon
# Processing Record 31 of Set 2 | bandarbeyla
# Processing Record 32 of Set 2 | farafangana
# Processing Record 33 of Set 2 | talnakh
# Processing Record 34 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 2 | cervo
# Processing Record 36 of Set 2 | cascais
# Processing Record 37 of Set 2 | ilulissat
# Processing Record 38 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 39 of Set 2 | kruisfontein
# Processing Record 40 of Set 2 | tual
# Processing Record 41 of Set 2 | pomichna
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | hibbing
# Processing Record 44 of Set 2 | bafoulabe
# Processing Record 45 of Set 2 | acopiara
# Processing Record 46 of Set 2 | bayan
# Processing Record 47 of Set 2 | punta arenas
# Processing Record 48 of Set 2 | anqing
# Processing Record 49 of Set 2 | xochihuehuetlan
# Processing Record 50 of Set 2 | iguape
# Processing Record 1 of Set 3 | takaungu
# Processing Record 2 of Set 3 | tateyama
# Processing Record 3 of Set 3 | miandrivazo
# Processing Record 4 of Set 3 | kahului
# Processing Record 5 of Set 3 | cape town
# Processing Record 6 of Set 3 | ayer itam
# City not found. Skipping...
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | cidreira
# Processing Record 9 of Set 3 | yellowknife
# Processing Record 10 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 3 | new norfolk
# Processing Record 12 of Set 3 | brae
# Processing Record 13 of Set 3 | zaysan
# Processing Record 14 of Set 3 | sri aman
# Processing Record 15 of Set 3 | kumla
# Processing Record 16 of Set 3 | broome
# Processing Record 17 of Set 3 | castro
# Processing Record 18 of Set 3 | namibe
# Processing Record 19 of Set 3 | constitucion
# Processing Record 20 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 3 | port hedland
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | devils lake
# Processing Record 24 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 3 | karratha
# Processing Record 26 of Set 3 | bethel
# Processing Record 27 of Set 3 | senneterre
# Processing Record 28 of Set 3 | imeni poliny osipenko
# Processing Record 29 of Set 3 | hilo
# Processing Record 30 of Set 3 | puerto carreno
# Processing Record 31 of Set 3 | hambantota
# Processing Record 32 of Set 3 | severo-kurilsk
# Processing Record 33 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 3 | saskylakh
# Processing Record 35 of Set 3 | albany
# Processing Record 36 of Set 3 | provideniya
# Processing Record 37 of Set 3 | byron bay
# Processing Record 38 of Set 3 | makakilo city
# Processing Record 39 of Set 3 | longyearbyen
# Processing Record 40 of Set 3 | jamestown
# Processing Record 41 of Set 3 | unye
# City not found. Skipping...
# Processing Record 42 of Set 3 | la serena
# Processing Record 43 of Set 3 | mahebourg
# Processing Record 44 of Set 3 | beloha
# Processing Record 45 of Set 3 | ca mau
# Processing Record 46 of Set 3 | kodiak
# Processing Record 47 of Set 3 | batagay
# Processing Record 48 of Set 3 | richards bay
# Processing Record 49 of Set 3 | fortuna
# Processing Record 50 of Set 3 | fort nelson
# Processing Record 1 of Set 4 | vao
# Processing Record 2 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 3 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 4 | dondo
# Processing Record 5 of Set 4 | karibib
# Processing Record 6 of Set 4 | dakar
# Processing Record 7 of Set 4 | nautla
# Processing Record 8 of Set 4 | banda aceh
# Processing Record 9 of Set 4 | kjollefjord
# Processing Record 10 of Set 4 | bengkulu
# Processing Record 11 of Set 4 | ventspils
# Processing Record 12 of Set 4 | savelugu
# Processing Record 13 of Set 4 | alice springs
# Processing Record 14 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 4 | hualmay
# Processing Record 16 of Set 4 | kupang
# Processing Record 17 of Set 4 | irece
# Processing Record 18 of Set 4 | adrar
# Processing Record 19 of Set 4 | tawzar
# City not found. Skipping...
# Processing Record 20 of Set 4 | petersburg
# Processing Record 21 of Set 4 | ponta do sol
# Processing Record 22 of Set 4 | marica
# Processing Record 23 of Set 4 | paracuru
# Processing Record 24 of Set 4 | dongning
# Processing Record 25 of Set 4 | necochea
# Processing Record 26 of Set 4 | mehamn
# Processing Record 27 of Set 4 | delhi
# Processing Record 28 of Set 4 | vanimo
# Processing Record 29 of Set 4 | arraial do cabo
# Processing Record 30 of Set 4 | szczecinek
# Processing Record 31 of Set 4 | lewisville
# Processing Record 32 of Set 4 | calabozo
# Processing Record 33 of Set 4 | kybartai
# Processing Record 34 of Set 4 | tabuk
# Processing Record 35 of Set 4 | pauini
# Processing Record 36 of Set 4 | yining
# Processing Record 37 of Set 4 | tiksi
# Processing Record 38 of Set 4 | obluche
# City not found. Skipping...
# Processing Record 39 of Set 4 | narsaq
# Processing Record 40 of Set 4 | nyurba
# Processing Record 41 of Set 4 | nouadhibou
# Processing Record 42 of Set 4 | puerto ayora
# Processing Record 43 of Set 4 | takoradi
# Processing Record 44 of Set 4 | thompson
# Processing Record 45 of Set 4 | panaba
# Processing Record 46 of Set 4 | los llanos de aridane
# Processing Record 47 of Set 4 | wigston
# Processing Record 48 of Set 4 | east london
# Processing Record 49 of Set 4 | grand-santi
# Processing Record 50 of Set 4 | boddam
# Processing Record 1 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 5 | atuona
# Processing Record 3 of Set 5 | saldanha
# Processing Record 4 of Set 5 | pendleton
# Processing Record 5 of Set 5 | fairbanks
# Processing Record 6 of Set 5 | torbay
# Processing Record 7 of Set 5 | pacific grove
# Processing Record 8 of Set 5 | tasiilaq
# Processing Record 9 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 5 | salamiyah
# Processing Record 11 of Set 5 | puerto escondido
# Processing Record 12 of Set 5 | butaritari
# Processing Record 13 of Set 5 | abalak
# Processing Record 14 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 15 of Set 5 | puerto cortes
# City not found. Skipping...
# Processing Record 16 of Set 5 | baie-saint-paul
# Processing Record 17 of Set 5 | coquimbo
# Processing Record 18 of Set 5 | olafsvik
# Processing Record 19 of Set 5 | prado
# Processing Record 20 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 21 of Set 5 | vostok
# Processing Record 22 of Set 5 | cookeville
# Processing Record 23 of Set 5 | halifax
# Processing Record 24 of Set 5 | saint-philippe
# Processing Record 25 of Set 5 | cabo san lucas
# Processing Record 26 of Set 5 | burgos
# Processing Record 27 of Set 5 | lorengau
# Processing Record 28 of Set 5 | seoul
# Processing Record 29 of Set 5 | dallas
# Processing Record 30 of Set 5 | bijawar
# Processing Record 31 of Set 5 | estevan
# Processing Record 32 of Set 5 | iralaya
# Processing Record 33 of Set 5 | jalu
# Processing Record 34 of Set 5 | sinazongwe
# Processing Record 35 of Set 5 | havelock
# Processing Record 36 of Set 5 | anadyr
# Processing Record 37 of Set 5 | pitimbu
# Processing Record 38 of Set 5 | londonderry
# Processing Record 39 of Set 5 | acas
# Processing Record 40 of Set 5 | margate
# Processing Record 41 of Set 5 | lufilufi
# Processing Record 42 of Set 5 | monrovia
# Processing Record 43 of Set 5 | alta floresta
# Processing Record 44 of Set 5 | hrusovany nad jevisovkou
# Processing Record 45 of Set 5 | ukiah
# Processing Record 46 of Set 5 | maroon town
# Processing Record 47 of Set 5 | iqaluit
# Processing Record 48 of Set 5 | hermiston
# Processing Record 49 of Set 5 | grand gaube
# Processing Record 50 of Set 5 | siolim
# City not found. Skipping...
# Processing Record 1 of Set 6 | laguna
# Processing Record 2 of Set 6 | half moon bay
# Processing Record 3 of Set 6 | uralets
# Processing Record 4 of Set 6 | antsohihy
# Processing Record 5 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 6 | dhidhdhoo
# Processing Record 7 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 6 | airai
# Processing Record 9 of Set 6 | prince albert
# Processing Record 10 of Set 6 | ariquemes
# Processing Record 11 of Set 6 | neftekamsk
# Processing Record 12 of Set 6 | santa cruz del norte
# Processing Record 13 of Set 6 | shimoda
# Processing Record 14 of Set 6 | sur
# Processing Record 15 of Set 6 | lexington
# Processing Record 16 of Set 6 | ribeira brava
# Processing Record 17 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 6 | kalaleh
# Processing Record 19 of Set 6 | angola
# Processing Record 20 of Set 6 | tezu
# Processing Record 21 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 22 of Set 6 | itarema
# Processing Record 23 of Set 6 | tautira
# Processing Record 24 of Set 6 | avera
# Processing Record 25 of Set 6 | san quintin
# Processing Record 26 of Set 6 | port macquarie
# Processing Record 27 of Set 6 | talara
# Processing Record 28 of Set 6 | taseyevo
# Processing Record 29 of Set 6 | mana
# Processing Record 30 of Set 6 | mwanza
# Processing Record 31 of Set 6 | linfen
# Processing Record 32 of Set 6 | shahrud
# Processing Record 33 of Set 6 | boende
# Processing Record 34 of Set 6 | san felipe
# Processing Record 35 of Set 6 | klaksvik
# Processing Record 36 of Set 6 | westport
# Processing Record 37 of Set 6 | lompoc
# Processing Record 38 of Set 6 | katangli
# Processing Record 39 of Set 6 | ryotsu
# Processing Record 40 of Set 6 | lewiston
# Processing Record 41 of Set 6 | kavaratti
# Processing Record 42 of Set 6 | ogaminana
# Processing Record 43 of Set 6 | sosnovo-ozerskoye
# Processing Record 44 of Set 6 | codrington
# Processing Record 45 of Set 6 | praia da vitoria
# Processing Record 46 of Set 6 | esna
# Processing Record 47 of Set 6 | rio grande
# Processing Record 48 of Set 6 | marsh harbour
# Processing Record 49 of Set 6 | otane
# Processing Record 50 of Set 6 | bathsheba
# Processing Record 1 of Set 7 | yilan
# Processing Record 2 of Set 7 | fatikchhari
# City not found. Skipping...
# Processing Record 3 of Set 7 | salme
# Processing Record 4 of Set 7 | kandrian
# Processing Record 5 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 7 | pinega
# Processing Record 7 of Set 7 | cayenne
# Processing Record 8 of Set 7 | statesboro
# Processing Record 9 of Set 7 | karpathos
# Processing Record 10 of Set 7 | port said
# Processing Record 11 of Set 7 | tubajon
# Processing Record 12 of Set 7 | beinamar
# Processing Record 13 of Set 7 | black river
# Processing Record 14 of Set 7 | owando
# Processing Record 15 of Set 7 | manavalakurichi
# Processing Record 16 of Set 7 | faanui
# Processing Record 17 of Set 7 | sao felix do xingu
# Processing Record 18 of Set 7 | leh
# Processing Record 19 of Set 7 | kyritz
# Processing Record 20 of Set 7 | bow island
# Processing Record 21 of Set 7 | chapais
# Processing Record 22 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 7 | chalons-en-champagne
# Processing Record 24 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 7 | sibu
# Processing Record 27 of Set 7 | carbonia
# Processing Record 28 of Set 7 | banyumas
# Processing Record 29 of Set 7 | port lincoln
# Processing Record 30 of Set 7 | yoichi
# Processing Record 31 of Set 7 | mapiri
# Processing Record 32 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 7 | kozhevnikovo
# Processing Record 34 of Set 7 | khatanga
# Processing Record 35 of Set 7 | belgrade
# Processing Record 36 of Set 7 | rio cuarto
# Processing Record 37 of Set 7 | tilichiki
# Processing Record 38 of Set 7 | kodinsk
# Processing Record 39 of Set 7 | pyay
# Processing Record 40 of Set 7 | presidente epitacio
# Processing Record 41 of Set 7 | vargashi
# Processing Record 42 of Set 7 | hami
# Processing Record 43 of Set 7 | funtua
# Processing Record 44 of Set 7 | aksarka
# Processing Record 45 of Set 7 | mar del plata
# Processing Record 46 of Set 7 | tugolesskiy bor
# Processing Record 47 of Set 7 | leningradskiy
# Processing Record 48 of Set 7 | texarkana
# Processing Record 49 of Set 7 | gorontalo
# Processing Record 50 of Set 7 | xuanhua
# Processing Record 1 of Set 8 | lokosovo
# Processing Record 2 of Set 8 | dzerzhinskoye
# Processing Record 3 of Set 8 | walvis bay
# Processing Record 4 of Set 8 | hovd
# Processing Record 5 of Set 8 | luz
# Processing Record 6 of Set 8 | gwadar
# Processing Record 7 of Set 8 | khani
# Processing Record 8 of Set 8 | sedro-woolley
# Processing Record 9 of Set 8 | santiago del estero
# Processing Record 10 of Set 8 | tuatapere
# Processing Record 11 of Set 8 | shkotovo-22
# City not found. Skipping...
# Processing Record 12 of Set 8 | norman wells
# Processing Record 13 of Set 8 | lata
# Processing Record 14 of Set 8 | teruel
# Processing Record 15 of Set 8 | shwebo
# Processing Record 16 of Set 8 | lagoa
# Processing Record 17 of Set 8 | santa rosa del sur
# Processing Record 18 of Set 8 | kargasok
# Processing Record 19 of Set 8 | la ronge
# Processing Record 20 of Set 8 | port blair
# Processing Record 21 of Set 8 | beyneu
# Processing Record 22 of Set 8 | bam
# Processing Record 23 of Set 8 | mount isa
# Processing Record 24 of Set 8 | lasa
# Processing Record 25 of Set 8 | gogrial
# Processing Record 26 of Set 8 | kayes
# Processing Record 27 of Set 8 | souillac
# Processing Record 28 of Set 8 | saint george
# Processing Record 29 of Set 8 | sao filipe
# Processing Record 30 of Set 8 | manavgat
# Processing Record 31 of Set 8 | padang
# Processing Record 32 of Set 8 | salalah
# Processing Record 33 of Set 8 | nadym
# Processing Record 34 of Set 8 | aklavik
# Processing Record 35 of Set 8 | balkanabat
# Processing Record 36 of Set 8 | rio tercero
# Processing Record 37 of Set 8 | sisimiut
# Processing Record 38 of Set 8 | quatre cocos
# Processing Record 39 of Set 8 | jinchang
# Processing Record 40 of Set 8 | naples
# Processing Record 41 of Set 8 | masallatah
# Processing Record 42 of Set 8 | kutum
# Processing Record 43 of Set 8 | arya
# Processing Record 44 of Set 8 | khorinsk
# Processing Record 45 of Set 8 | riberalta
# Processing Record 46 of Set 8 | angoche
# Processing Record 47 of Set 8 | lugovoy
# Processing Record 48 of Set 8 | berlevag
# Processing Record 49 of Set 8 | pisco
# Processing Record 50 of Set 8 | niimi
# Processing Record 1 of Set 9 | san juan
# Processing Record 2 of Set 9 | erenhot
# Processing Record 3 of Set 9 | hirara
# Processing Record 4 of Set 9 | meulaboh
# Processing Record 5 of Set 9 | poum
# Processing Record 6 of Set 9 | vilhena
# Processing Record 7 of Set 9 | eureka
# Processing Record 8 of Set 9 | sudak
# Processing Record 9 of Set 9 | lodja
# Processing Record 10 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 11 of Set 9 | carutapera
# Processing Record 12 of Set 9 | tokur
# Processing Record 13 of Set 9 | smidovich
# Processing Record 14 of Set 9 | zaliztsi
# Processing Record 15 of Set 9 | cap malheureux
# Processing Record 16 of Set 9 | zhanakorgan
# Processing Record 17 of Set 9 | namatanai
# Processing Record 18 of Set 9 | nieuw amsterdam
# Processing Record 19 of Set 9 | ancud
# Processing Record 20 of Set 9 | soverato
# Processing Record 21 of Set 9 | surt
# Processing Record 22 of Set 9 | codajas
# Processing Record 23 of Set 9 | hvolsvollur
# Processing Record 24 of Set 9 | gamba
# Processing Record 25 of Set 9 | pabrade
# Processing Record 26 of Set 9 | esperance
# Processing Record 27 of Set 9 | tharad
# Processing Record 28 of Set 9 | tabou
# Processing Record 29 of Set 9 | misratah
# Processing Record 30 of Set 9 | canutama
# Processing Record 31 of Set 9 | marau
# Processing Record 32 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 9 | orikum
# Processing Record 34 of Set 9 | karpenision
# City not found. Skipping...
# Processing Record 35 of Set 9 | mudanya
# Processing Record 36 of Set 9 | bollnas
# Processing Record 37 of Set 9 | sawai madhopur
# Processing Record 38 of Set 9 | karpogory
# Processing Record 39 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 40 of Set 9 | broken hill
# Processing Record 41 of Set 9 | kingaroy
# Processing Record 42 of Set 9 | collie
# Processing Record 43 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 44 of Set 9 | grindavik
# Processing Record 45 of Set 9 | yulara
# Processing Record 46 of Set 9 | praia
# Processing Record 47 of Set 9 | ayan
# Processing Record 48 of Set 9 | rudbar
# Processing Record 49 of Set 9 | thoen
# Processing Record 50 of Set 9 | ouesso
# Processing Record 1 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 2 of Set 10 | garden city
# Processing Record 3 of Set 10 | piacabucu
# Processing Record 4 of Set 10 | kaitangata
# Processing Record 5 of Set 10 | road town
# Processing Record 6 of Set 10 | henties bay
# Processing Record 7 of Set 10 | lisakovsk
# Processing Record 8 of Set 10 | nizwa
# Processing Record 9 of Set 10 | caravelas
# Processing Record 10 of Set 10 | qarqin
# Processing Record 11 of Set 10 | najran
# Processing Record 12 of Set 10 | tyler
# Processing Record 13 of Set 10 | ola
# Processing Record 14 of Set 10 | weligama
# Processing Record 15 of Set 10 | jiuquan
# Processing Record 16 of Set 10 | ihosy
# Processing Record 17 of Set 10 | shenandoah
# Processing Record 18 of Set 10 | raudeberg
# Processing Record 19 of Set 10 | kuusamo
# Processing Record 20 of Set 10 | ixtapa
# Processing Record 21 of Set 10 | san patricio
# Processing Record 22 of Set 10 | waipawa
# Processing Record 23 of Set 10 | nybro
# Processing Record 24 of Set 10 | khilok
# Processing Record 25 of Set 10 | gayny
# Processing Record 26 of Set 10 | labuhan
# Processing Record 27 of Set 10 | gaoua
# Processing Record 28 of Set 10 | touros
# Processing Record 29 of Set 10 | acuna
# City not found. Skipping...
# Processing Record 30 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 31 of Set 10 | flin flon
# Processing Record 32 of Set 10 | bonthe
# Processing Record 33 of Set 10 | oban
# Processing Record 34 of Set 10 | egvekinot
# Processing Record 35 of Set 10 | north bend
# Processing Record 36 of Set 10 | salinas
# Processing Record 37 of Set 10 | itamaraca
# Processing Record 38 of Set 10 | wamba
# Processing Record 39 of Set 10 | kieta
# Processing Record 40 of Set 10 | kangasala
# Processing Record 41 of Set 10 | mogadishu
# Processing Record 42 of Set 10 | donskoye
# Processing Record 43 of Set 10 | imst
# Processing Record 44 of Set 10 | brun
# Processing Record 45 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 10 | geraldton
# Processing Record 47 of Set 10 | bima
# Processing Record 48 of Set 10 | xihe
# Processing Record 49 of Set 10 | sola
# Processing Record 50 of Set 10 | srednekolymsk
# Processing Record 1 of Set 11 | zaykovo
# Processing Record 2 of Set 11 | belle fourche
# Processing Record 3 of Set 11 | nara
# Processing Record 4 of Set 11 | asfi
# Processing Record 5 of Set 11 | samarai
# Processing Record 6 of Set 11 | vanavara
# Processing Record 7 of Set 11 | labuan
# Processing Record 8 of Set 11 | pucallpa
# Processing Record 9 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 10 of Set 11 | san policarpo
# Processing Record 11 of Set 11 | pangnirtung
# Processing Record 12 of Set 11 | menongue
# Processing Record 13 of Set 11 | grand forks
# Processing Record 14 of Set 11 | kuroiso
# Processing Record 15 of Set 11 | kandalaksha
# Processing Record 16 of Set 11 | mount gambier
# Processing Record 17 of Set 11 | vila velha
# Processing Record 18 of Set 11 | banes
# Processing Record 19 of Set 11 | fukue
# Processing Record 20 of Set 11 | xiaolingwei
# Processing Record 21 of Set 11 | mandalgovi
# Processing Record 22 of Set 11 | komsomolskiy
# Processing Record 23 of Set 11 | zhigansk
# Processing Record 24 of Set 11 | pevek
# Processing Record 25 of Set 11 | karasuk
# Processing Record 26 of Set 11 | yerbogachen
# Processing Record 27 of Set 11 | faya
# Processing Record 28 of Set 11 | naze
# Processing Record 29 of Set 11 | sovetskiy
# Processing Record 30 of Set 11 | te anau
# Processing Record 31 of Set 11 | jeremie
# Processing Record 32 of Set 11 | udachnyy
# Processing Record 33 of Set 11 | alyangula
# Processing Record 34 of Set 11 | yar-sale
# Processing Record 35 of Set 11 | balikpapan
# Processing Record 36 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 37 of Set 11 | ust-kuyga
# Processing Record 38 of Set 11 | krasni okny
# Processing Record 39 of Set 11 | tabas
# Processing Record 40 of Set 11 | atambua
# Processing Record 41 of Set 11 | mariakani
# Processing Record 42 of Set 11 | iskateley
# Processing Record 43 of Set 11 | wanning
# Processing Record 44 of Set 11 | kalmar
# Processing Record 45 of Set 11 | cao bang
# Processing Record 46 of Set 11 | san nicolas
# Processing Record 47 of Set 11 | morant bay
# Processing Record 48 of Set 11 | erdenet
# Processing Record 49 of Set 11 | bayir
# Processing Record 50 of Set 11 | doha
# Processing Record 1 of Set 12 | zarubino
# Processing Record 2 of Set 12 | noumea
# Processing Record 3 of Set 12 | dera din panah
# City not found. Skipping...
# Processing Record 4 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 12 | okato
# Processing Record 7 of Set 12 | holalkere
# Processing Record 8 of Set 12 | sao joao da barra
# Processing Record 9 of Set 12 | pemangkat
# Processing Record 10 of Set 12 | tongliao
# Processing Record 11 of Set 12 | bubaque
# Processing Record 12 of Set 12 | teya
# Processing Record 13 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 12 | victoria point
# Processing Record 15 of Set 12 | nyuksenitsa
# Processing Record 16 of Set 12 | ambovombe
# Processing Record 17 of Set 12 | birin
# Processing Record 18 of Set 12 | nuevo progreso
# Processing Record 19 of Set 12 | kamenka
# Processing Record 20 of Set 12 | sinnamary
# Processing Record 21 of Set 12 | arman
# Processing Record 22 of Set 12 | mukdahan
# Processing Record 23 of Set 12 | yuancheng
# Processing Record 24 of Set 12 | nyimba
# Processing Record 25 of Set 12 | manuk mangkaw
# Processing Record 26 of Set 12 | gat
# Processing Record 27 of Set 12 | newcastle
# Processing Record 28 of Set 12 | vila franca do campo
# Processing Record 29 of Set 12 | nakamura
# Processing Record 30 of Set 12 | ust-uda
# Processing Record 31 of Set 12 | uige
# Processing Record 32 of Set 12 | treinta y tres
# Processing Record 33 of Set 12 | abu dhabi
# Processing Record 34 of Set 12 | estelle
# Processing Record 35 of Set 12 | korla
# Processing Record 36 of Set 12 | lavrentiya
# Processing Record 37 of Set 12 | yamada
# Processing Record 38 of Set 12 | grants pass
# Processing Record 39 of Set 12 | goderich
# Processing Record 40 of Set 12 | waitati
# Processing Record 41 of Set 12 | lac du bonnet
# Processing Record 42 of Set 12 | hofn
# Processing Record 43 of Set 12 | ulaanbaatar
# Processing Record 44 of Set 12 | barcelona
# Processing Record 45 of Set 12 | jatai
# Processing Record 46 of Set 12 | burriana
# Processing Record 47 of Set 12 | harper
# Processing Record 48 of Set 12 | qandala
# Processing Record 49 of Set 12 | parrita
# Processing Record 50 of Set 12 | moroni
# Processing Record 1 of Set 13 | oksfjord
# Processing Record 2 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 13 | verkhoyansk
# Processing Record 4 of Set 13 | yerofey pavlovich
# Processing Record 5 of Set 13 | nelson bay
# Processing Record 6 of Set 13 | hobyo
# Processing Record 7 of Set 13 | pitelino
# Processing Record 8 of Set 13 | tarakan
# Processing Record 9 of Set 13 | south lake tahoe
# Processing Record 10 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 13 | santa cruz
# Processing Record 12 of Set 13 | saint anthony
# Processing Record 13 of Set 13 | sabya
# Processing Record 14 of Set 13 | barcelos
# Processing Record 15 of Set 13 | frontino
# Processing Record 16 of Set 13 | abadiania
# Processing Record 17 of Set 13 | champerico
# Processing Record 18 of Set 13 | batagay-alyta
# Processing Record 19 of Set 13 | terenos
# Processing Record 20 of Set 13 | issia
# Processing Record 21 of Set 13 | svetlaya
# Processing Record 22 of Set 13 | uk
# City not found. Skipping...
# Processing Record 23 of Set 13 | prince rupert
# Processing Record 24 of Set 13 | jiroft
# City not found. Skipping...
# Processing Record 25 of Set 13 | malindi
# Processing Record 26 of Set 13 | newport
# Processing Record 27 of Set 13 | emerald
# Processing Record 28 of Set 13 | asau
# Processing Record 29 of Set 13 | puerto el triunfo
# Processing Record 30 of Set 13 | nizhniy mamon
# Processing Record 31 of Set 13 | semporna
# Processing Record 32 of Set 13 | doka
# Processing Record 33 of Set 13 | na wa
# Processing Record 34 of Set 13 | magadan
# Processing Record 35 of Set 13 | ravar
# Processing Record 36 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 38 of Set 13 | shingu
# Processing Record 39 of Set 13 | redcar
# Processing Record 40 of Set 13 | dagda
# Processing Record 41 of Set 13 | tecoanapa
# Processing Record 42 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 13 | kununurra
# Processing Record 44 of Set 13 | ambon
# Processing Record 45 of Set 13 | vestmannaeyjar
# Processing Record 46 of Set 13 | kotaparh
# Processing Record 47 of Set 13 | santarem
# Processing Record 48 of Set 13 | paraiso
# Processing Record 49 of Set 13 | mezhova
# Processing Record 50 of Set 13 | entebbe
# Processing Record 1 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 14 | yeppoon
# Processing Record 3 of Set 14 | petatlan
# Processing Record 4 of Set 14 | bhalwal
# Processing Record 5 of Set 14 | karatau
# Processing Record 6 of Set 14 | finschhafen
# Processing Record 7 of Set 14 | swan hill
# Processing Record 8 of Set 14 | prieska
# Processing Record 9 of Set 14 | lazaro cardenas
# Processing Record 10 of Set 14 | ondjiva
# Processing Record 11 of Set 14 | miajadas
# Processing Record 12 of Set 14 | blythe
# Processing Record 13 of Set 14 | blacksburg
# Processing Record 14 of Set 14 | ohafia
# Processing Record 15 of Set 14 | buala
# Processing Record 16 of Set 14 | vallenar
# Processing Record 17 of Set 14 | rawah
# Processing Record 18 of Set 14 | tashtagol
# Processing Record 19 of Set 14 | elban
# Processing Record 20 of Set 14 | kamaishi
# Processing Record 21 of Set 14 | zyryanka
# Processing Record 22 of Set 14 | penalva
# Processing Record 23 of Set 14 | gravdal
# Processing Record 24 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 25 of Set 14 | chabahar
# Processing Record 26 of Set 14 | severobaykalsk
# Processing Record 27 of Set 14 | razdolinsk
# Processing Record 28 of Set 14 | nioro
# Processing Record 29 of Set 14 | ye
# City not found. Skipping...
# Processing Record 30 of Set 14 | subaytilah
# City not found. Skipping...
# Processing Record 31 of Set 14 | joplin
# Processing Record 32 of Set 14 | donegal
# Processing Record 33 of Set 14 | araouane
# Processing Record 34 of Set 14 | lloydminster
# Processing Record 35 of Set 14 | baghdad
# Processing Record 36 of Set 14 | chara
# Processing Record 37 of Set 14 | salinopolis
# Processing Record 38 of Set 14 | dali
# Processing Record 39 of Set 14 | balimo
# City not found. Skipping...
# Processing Record 40 of Set 14 | porto torres
# Processing Record 41 of Set 14 | spring valley
# Processing Record 42 of Set 14 | bushehr
# Processing Record 43 of Set 14 | aljezur
# Processing Record 44 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 45 of Set 14 | minot
# Processing Record 46 of Set 14 | comodoro rivadavia
# Processing Record 47 of Set 14 | antofagasta
# Processing Record 48 of Set 14 | marawi
# Processing Record 49 of Set 14 | sindou
# Processing Record 50 of Set 14 | nome
# Processing Record 1 of Set 15 | sokoni
# Processing Record 2 of Set 15 | ahumada
# City not found. Skipping...
# Processing Record 3 of Set 15 | emba
# Processing Record 4 of Set 15 | sundumbili
# Processing Record 5 of Set 15 | umm kaddadah
# Processing Record 6 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 7 of Set 15 | kandi
# Processing Record 8 of Set 15 | mitsamiouli
# Processing Record 9 of Set 15 | xingyi
# Processing Record 10 of Set 15 | quimperle
# Processing Record 11 of Set 15 | chernyshevskiy
# Processing Record 12 of Set 15 | kavali
# Processing Record 13 of Set 15 | tambun
# Processing Record 14 of Set 15 | hanna
# Processing Record 15 of Set 15 | port hardy
# Processing Record 16 of Set 15 | high rock
# Processing Record 17 of Set 15 | ayagoz
# Processing Record 18 of Set 15 | palmer
# Processing Record 19 of Set 15 | sokol
# Processing Record 20 of Set 15 | timizart
# Processing Record 21 of Set 15 | plainview
# Processing Record 22 of Set 15 | parry sound
# Processing Record 23 of Set 15 | gao
# Processing Record 24 of Set 15 | barberino di mugello
# Processing Record 25 of Set 15 | itambacuri
# Processing Record 26 of Set 15 | kungurtug
# Processing Record 27 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 28 of Set 15 | coron
# Processing Record 29 of Set 15 | kapit
# Processing Record 30 of Set 15 | parabel
# Processing Record 31 of Set 15 | coihaique
# Processing Record 32 of Set 15 | lakes entrance
# Processing Record 33 of Set 15 | cheyenne
# Processing Record 34 of Set 15 | imeni babushkina
# Processing Record 35 of Set 15 | rantepao
# Processing Record 36 of Set 15 | zelenogorskiy
# Processing Record 37 of Set 15 | belleville
# Processing Record 38 of Set 15 | okha
# Processing Record 39 of Set 15 | lewistown
# Processing Record 40 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 15 | bekhteyevka
# Processing Record 42 of Set 15 | campo gobierno
# Processing Record 43 of Set 15 | midland
# Processing Record 44 of Set 15 | hay river
# Processing Record 45 of Set 15 | rawa mazowiecka
# Processing Record 46 of Set 15 | malanje
# Processing Record 47 of Set 15 | cam ranh
# Processing Record 48 of Set 15 | wakkanai
# Processing Record 49 of Set 15 | havre-saint-pierre
# Processing Record 50 of Set 15 | tagusao
# Processing Record 1 of Set 16 | santa cruz de tenerife
# Processing Record 2 of Set 16 | belaya gora
# Processing Record 3 of Set 16 | aktau
# Processing Record 4 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 16 | pundaguitan
# Processing Record 6 of Set 16 | kulhudhuffushi
# Processing Record 7 of Set 16 | launceston
# Processing Record 8 of Set 16 | dauphin
# Processing Record 9 of Set 16 | sidi qasim
# City not found. Skipping...
# Processing Record 10 of Set 16 | simbahan
# Processing Record 11 of Set 16 | sunrise manor
# Processing Record 12 of Set 16 | la tour-de-peilz
# Processing Record 13 of Set 16 | rawson
# Processing Record 14 of Set 16 | curaca
# Processing Record 15 of Set 16 | poya
# Processing Record 16 of Set 16 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 16 | carrefour
# Processing Record 18 of Set 16 | kapustin yar
# Processing Record 19 of Set 16 | kholodnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 699

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

city_data_df.head(15)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Hobart      AU -42.8794  147.3294     46.11        81
# 1          Rajanpur      PK  29.1035   70.3250     91.26        50
# 2           Qaanaaq      GL  77.4840  -69.3632     42.37        62
# 3           Borovoy      RU  55.4333   86.0833     67.28        77
# 4            Avarua      CK -21.2078 -159.7750     78.85        69
# 5   Puerto Colombia      CO  10.9878  -74.9547     86.09        87
# 6          Ambilobe      MG -13.2000   49.0500     64.22        84
# 7           Tricase      IT  39.9304   18.3553     79.95        62
# 8       Clyde River      CA  70.4692  -68.5914     37.63        87
# 9       Port Alfred      ZA -33.5906   26.8910     52.81        67
# 10             Chuy      UY -33.6971  -53.4616     59.72        87
# 11      Warrnambool      AU -38.3833  142.4833     49.80        88
# 12            Izumo      JP  35.3667  132.7667     78.75        83
# 13            Sitka      US  57.0531 -135.3300     57.09        88
# 14           Anloga      GH   5.7947    0.8973     77.22        84
#
#     Cloudiness  Wind Speed Current Description
# 0           75        1.99       broken clouds
# 1           85       14.00     overcast clouds
# 2           23        3.85          few clouds
# 3            0        4.47           clear sky
# 4           20       11.50          few clouds
# 5           95       18.48     overcast clouds
# 6            0        3.83           clear sky
# 7            0        8.86           clear sky
# 8           90       18.41     overcast clouds
# 9           98        4.70     overcast clouds
# 10           5        4.14          light rain
# 11          78       25.77          light rain
# 12           0        8.05           clear sky
# 13          75       10.36          light rain
# 14          64       11.74       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
